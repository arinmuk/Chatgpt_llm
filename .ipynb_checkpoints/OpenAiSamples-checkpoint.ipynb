# %%
import os

key="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"

os.environ['OPENAI_API_KEY']=key

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5-nano",
    input="i want to open a restaurant for Thai food. Suggest a fancy name for this."
)

print(response.output_text)
# Out:
# Nice idea! Here are some fancy Thai restaurant name options to choose from or inspire you. Each has a refined vibe, with a mix of Thai language touches and elegant English.
#
# - Sala Siam — evokes a refined pavilion in Siam (Thai sophistication)
# - Apsara Thai — celestial Thai dancers, graceful dining
# - Lanna Silk Thai — Northern Thai heritage, luxurious feel
# - Kinnaree Kitchen — mythical beauty, bold flavors
# - Baan Thai Atelier — home of Thai artistry and craft
# - Rattanakosin Royale Thai — historic Bangkok grandeur
# - Sukhothai Elan — timeless Thai elegance
# - Golden Orchid Thai — opulent, fragrant imagery
# - Siamese Velvet — plush, sophisticated Thai dining
# - Banyan Thai House — rooted, serene, upscale
# - Orchid & Ember Thai — delicate charm with bold warmth
# - Chada Royale Thai — moonlit luxury and refinement
# - Mekhala Thai — goddess of light, luminous dining
# - Ayutthaya Grande Thai — historic grandeur, modern polish
# - Ayara Thai — noble, elegant, timeless
# - Naga Jade Thai — mythical serpent with green jade luxury
# - Siam Soirée — stylish Thai soirée
# - Silk & Spice Siam — luxe, textural, and flavorful
#
# If you share your vibe (classic vs modern, regional nods like Lanna or Ayutthaya, target price point, or location), I can tailor a shortlist or brainstorm even more options. Also I can help with logo/tagline ideas and checking name availability.
