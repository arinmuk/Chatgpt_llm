# %%
import os

from config import key

os.environ['OPENAI_API_KEY']=key

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5-nano",
    input="i want to open a restaurant for Thai food. Suggest a fancy name for this."
)

print(response.output_text)
# Out:
# Here are some fancy Thai restaurant name ideas to spark your branding. I’ve included a mix of elegant, modern, and Thai-inspired options:
#
# - Siam Silk & Spice
# - Royal Chao Praya
# - Dusit Dynasty Thai
# - Lanna Luxe Thai
# - Bangkok Velvet
# - Sukhothai Reverie
# - Kinnaree & Co.
# - Apsara Atelier
# - Rattanakosin Table
# - Ayutthaya Alchemy
# - Sala Siam
# - Chantara Thai
# - Praya Pearl
# - Lotus & Lattice Thai
# - Niran Thai
# - Emerald Siam
# - Patara Thai
# - Siam Reverie
#
# If you share the vibe you want (royal and opulent, modern minimalist, rustic/heritage, or fusion), I can tailor a fresh set and even help with taglines and domain ideas.
