# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5-nano",
    input="i want to open a restaurant for Indian food. Suggest a fancy name for this."
)

print(response.output_text)
# Out:
# Here are some fancy Indian restaurant name ideas across different vibes. Pick the vibe you like, and I can tailor more:
#
# Regal/heritage
# - Rajwada Reverie
# - Shahi Tandoor
# - Mughal Masala
# - Rasoi Royale
# - Kesar Mahal
# - Shalimar Spice Room
# - Darbar Delicacies
# - Taj & Tadka
#
# Elegant/modern
# - Saffron Silk
# - Silk Route Kitchen
# - Spice Atelier
# - Rasa Regal
# - Spice Caravan
# - Spice & Saffron Court
#
# Warm, inviting
# - Nawaabi Nook
# - Delhi Darbar
# - Heritage Flame
# - Zaika & Zest
# - Swaad Palace
#
# Classic Indian flavors
# - The Silk Spoon
# - Rasoi Royale
# - Indus Ember
# - Bombay Masala House
#
# If you share your city, target crowd (fine-dine vs casual), and any words you want included or avoided, I’ll tailor a shortlist and even brainstorm taglines.

# %%
#from openai import OpenAI
import os

from config import key

os.environ['OPENAI_API_KEY']=key
from langchain_openai.llms import OpenAI

# %%
from langchain_openai.llms import OpenAI
llm = OpenAI()#(model="gpt-5-nano",temperature=0.6)
name = llm.invoke(" i want to open a restaurant for Indian food. Suggest a fancy name for this")
#name = llm(" i want to open a restaurant for Indian food. Suggest a fancy name for this")
print(name)
# Out:
#  restaurant
#
# "Maharaja's Palace: A Taste of India"

# %%
#client=OpenAI(api_key=key)
#llm = OpenAI(temperature=0.6)
client = OpenAI()

response = client.client.create(
  model="gpt-5-nano",
  prompt="i want to open a restaurant for Indian food. Suggest a fancy name for this"
)
#name = llm(" i want to open a restaurant for Indian food. Suggest a fancy name for this")
#print(name)
print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[33], line 5
#       1 #client=OpenAI(api_key=key)
#       2 #llm = OpenAI(temperature=0.6)
#       3 client = OpenAI()
# ----> 5 response = client.client.create(
#       6   model="gpt-5-nano",
#       7   prompt="i want to open a restaurant for Indian food. Suggest a fancy name for this"
#       8 )
#       9 #name = llm(" i want to open a restaurant for Indian food. Suggest a fancy name for this")
#      10 #print(name)
#      11 print(response.output_text)
#
# File ~\.conda\envs\envLLM\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\.conda\envs\envLLM\Lib\site-packages\openai\resources\completions.py:541, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     512 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     513 def create(
#     514     self,
#    (...)    539     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     540 ) -> Completion | Stream[Completion]:
# --> 541     return self._post(
#     542         "/completions",
#     543         body=maybe_transform(
#     544             {
#     545                 "model": model,
#     546                 "prompt": prompt,
#     547                 "best_of": best_of,
#     548                 "echo": echo,
#     549                 "frequency_penalty": frequency_penalty,
#     550                 "logit_bias": logit_bias,
#     551                 "logprobs": logprobs,
#     552                 "max_tokens": max_tokens,
#     553                 "n": n,
#     554                 "presence_penalty": presence_penalty,
#     555                 "seed": seed,
#     556                 "stop": stop,
#     557                 "stream": stream,
#     558                 "stream_options": stream_options,
#     559                 "suffix": suffix,
#     560                 "temperature": temperature,
#     561                 "top_p": top_p,
#     562                 "user": user,
#     563             },
#     564             completion_create_params.CompletionCreateParamsStreaming
#     565             if stream
#     566             else completion_create_params.CompletionCreateParamsNonStreaming,
#     567         ),
#     568         options=make_request_options(
#     569             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     570         ),
#     571         cast_to=Completion,
#     572         stream=stream or False,
#     573         stream_cls=Stream[Completion],
#     574     )
#
# File ~\.conda\envs\envLLM\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\.conda\envs\envLLM\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'This is a chat model and not supported in the v1/completions endpoint. Did you mean to use v1/chat/completions?', 'type': 'invalid_request_error', 'param': 'model', 'code': None}}

# %%
#from langchain.prompts import PromptTemplate
from langchain_core.prompts import PromptTemplate
prompt_template_name = PromptTemplate(
        input_variables=["cusine"],
        template = 'i want to open a restaurant for {cusine} food. Suggest a fancy name for this'
)
prompt_template_name.format(cusine='italian')
# Out:
# 'i want to open a restaurant for italian food. Suggest a fancy name for this'

# %%
# Correct import for PromptTemplate
from langchain_classic.prompts import PromptTemplate
prompt_template_name = PromptTemplate(
        input_variables=["cusine"],
        template = 'i want to open a restaurant for {cusine} food. Suggest a fancy name for this'
)
prompt_template_name.format(cusine='italian')
# Out:
# 'i want to open a restaurant for italian food. Suggest a fancy name for this'

# %%
from langchain_classic.chains import LLMChain
chain=LLMChain(llm=response, prompt = prompt_template_name)
chain.run('mexican')
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[23], line 2
#       1 from langchain_classic.chains import LLMChain
# ----> 2 chain=LLMChain(llm=response, prompt = prompt_template_name)
#       3 chain.run('mexican')
#
# File ~\.conda\envs\envLLM\Lib\site-packages\langchain_core\_api\deprecation.py:221, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     219     warned = True
#     220     emit_warning()
# --> 221 return wrapped(self, *args, **kwargs)
#
# File ~\.conda\envs\envLLM\Lib\site-packages\langchain_core\load\serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
# File ~\.conda\envs\envLLM\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 2 validation errors for LLMChain
# llm.is-instance[Runnable]
#   Input should be an instance of Runnable [type=is_instance_of, input_value=Response(id='resp_04b00ab...ention=None, store=True), input_type=Response]
#     For further information visit https://errors.pydantic.dev/2.12/v/is_instance_of
# llm.is-instance[Runnable]
#   Input should be an instance of Runnable [type=is_instance_of, input_value=Response(id='resp_04b00ab...ention=None, store=True), input_type=Response]
#     For further information visit https://errors.pydantic.dev/2.12/v/is_instance_of
